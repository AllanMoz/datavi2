# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from datetime import datetime as dt

# %%
gg = pd.read_csv('USA_DISEASES.csv').drop(columns = ['Unnamed: 0','MMWR Week','MMWR Year',                                                    'Jurisdiction of Occurrence'])

gg['Week Ending Date'] = pd.to_datetime(gg['Week Ending Date'])
gg = gg.set_index('Week Ending Date')

gg_sum = gg.groupby(pd.Grouper(freq="M")).sum().reset_index()
gg_mean = gg.groupby(pd.Grouper(freq="M")).mean().reset_index()

# %%
gg_sum
# Out:
#    Week Ending Date  All Cause  Natural Cause  Septicemia  \
# 0        2014-01-31   264027.0       245261.0      4164.0
# 1        2014-02-28   153756.0       142482.0      2230.0
# 2        2014-03-31   204082.0       189248.0      3094.0
# 3        2014-04-30   202495.0       187270.0      3060.0
# 4        2014-05-31   243429.0       224126.0      3517.0
# ..              ...        ...            ...         ...
# 82       2020-11-30   276338.0       256247.0      3098.0
# 83       2020-12-31   315269.0       296878.0      3232.0
# 84       2021-01-31   397544.0       377654.0      3911.0
# 85       2021-02-28   242548.0       231812.0      2789.0
# 86       2021-03-31    72190.0        70147.0       871.0
#
#     Malignant neoplasms  Diabetes mellitus  Alzheimer  \
# 0               57427.0             7807.0     9356.0
# 1               34353.0             4555.0     5192.0
# 2               45515.0             6050.0     6960.0
# ...

# %%
gg_mean
# Out:
#    Week Ending Date  All Cause  Natural Cause  Septicemia  \
# 0        2014-01-31   52805.40       49052.20  832.800000
# 1        2014-02-28   51252.00       47494.00  743.333333
# 2        2014-03-31   51020.50       47312.00  773.500000
# 3        2014-04-30   50623.75       46817.50  765.000000
# 4        2014-05-31   48685.80       44825.20  703.400000
# ..              ...        ...            ...         ...
# 82       2020-11-30   69084.50       64061.75  774.500000
# 83       2020-12-31   78817.25       74219.50  808.000000
# 84       2021-01-31   79508.80       75530.80  782.200000
# 85       2021-02-28   60637.00       57953.00  697.250000
# 86       2021-03-31   36095.00       35073.50  435.500000
#
#     Malignant neoplasms  Diabetes mellitus    Alzheimer  \
# 0              11485.40        1561.400000  1871.200000
# 1              11451.00        1518.333333  1730.666667
# 2              11378.75        1512.500000  1740.000000
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(x=gg_sum_month['Week Ending Date'], y=gg_sum_month['Alzheimer'],
                    mode='lines',
                    name='All Cause'))
fig.add_trace(go.Scatter(x=gg_sum_month['Week Ending Date'], y=gg_sum_month['Diabetes mellitus'],
                    mode='lines',
                    name='Natural Cause'))


fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fba030e65fd6> in <module>
#       3 fig = go.Figure()
#       4
# ----> 5 fig.add_trace(go.Scatter(x=gg_sum_month['Week Ending Date'], y=gg_sum_month['Alzheimer'],
#       6                     mode='lines',
#       7                     name='All Cause'))
#
# NameError: name 'gg_sum_month' is not defined

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(x=gg_mean_month['Week Ending Date'], y=gg_mean_month['Alzheimer'],
                    mode='lines',
                    name='All Cause'))
fig.add_trace(go.Scatter(x=gg_mean_month['Week Ending Date'], y=gg_mean_month['Diabetes mellitus'],
                    mode='lines',
                    name='Natural Cause'))

fig.show()

# %%
def lineplot(disease, time, agg):
    
    if time == 'Monthly':
        if agg == 'Mean':
            df = gg.groupby(pd.Grouper(freq="M")).mean().reset_index()
        elif agg == 'Sum':
            df = gg.groupby(pd.Grouper(freq="M")).sum().reset_index()
    elif time == 'Yearly':
        if agg == 'Mean':
            df = gg.groupby(pd.Grouper(freq="Y")).mean().reset_index()
        elif agg == 'Sum':
            df = gg.groupby(pd.Grouper(freq="Y")).sum().reset_index()

    fig = go.Figure()
    
    fig.add_trace(go.Scatter(x=df['Week Ending Date'], y=df[disease],
        mode='lines',
        name=str(disease)))

    fig.show()

# %%
lineplot('Diabetes mellitus', 'Yearly', 'Mean')

# %%
import plotly.express as px

def lineplot(disease, time, agg):
    gg = pd.read_csv('USA_DISEASES.csv').drop(columns = ['Unnamed: 0','MMWR Week','MMWR Year','Jurisdiction of Occurrence'])

    gg['Week Ending Date'] = pd.to_datetime(gg['Week Ending Date'])
    gg = gg.set_index('Week Ending Date')
    colory = ['rgb(0, 147, 146)', 'rgb(114, 170, 161)', 'rgb(177, 199, 179)', 
              'rgb(241, 234, 200)', 'rgb(229, 185, 173)', 'rgb(217, 137, 148)', 
              'rgb(208, 88, 126)', 'rgb(241, 234, 200)', 'rgb(229, 185, 173)', 
              'rgb(217, 137, 148)','rgb(241, 234, 200)', 'rgb(229, 185, 173)', 'rgb(217, 137, 148)']
    df1 = gg.groupby(pd.Grouper(freq="Y")).mean().reset_index()
    data_line = []
    colory = []

    for i in range(len(disease)):
        
        if time == 1:
            if agg == 0:
                df1 = gg.groupby(pd.Grouper(freq="M")).mean().reset_index()
            elif agg == 1:
                df1 = gg.groupby(pd.Grouper(freq="M")).sum().reset_index()
        elif time == 0:
            if agg == 0:
                df1 = gg.groupby(pd.Grouper(freq="Y")).mean().reset_index()
            elif agg == 1:
                df1 = gg.groupby(pd.Grouper(freq="Y")).sum().reset_index()
        data_line.append(dict(type='scatter',x=df1['Week Ending Date'],y=df1[disease[i]], 
                              mode='lines', line=dict(color = colory[i]), 
                              legend=dict(orientation="h",yanchor="bottom",y=1.02,
                                xanchor="right",x=1)
                             )
                        )
    
    return go.Figure(data=data_line)

# %%
lineplot(['All Cause', 'Diabetes mellitus', 'Natural Cause'], 1, 1)

# %%
gg_sum_month = gg.groupby(pd.Grouper(freq="M")).sum().reset_index()
gg_mean_month = gg.groupby(pd.Grouper(freq="M")).mean().reset_index()
gg_sum_year = gg.groupby(pd.Grouper(freq="Y")).sum().reset_index()
gg_mean_year = gg.groupby(pd.Grouper(freq="Y")).mean().reset_index()

# %%
gg_sum_month

# %%
df = pd.read_csv('USA_DISEASES.csv').drop(columns = ['Unnamed: 0', 'MMWR Year','MMWR Week', 'Jurisdiction of Occurrence'])

# %%
df

# %%
XXXXX

# %%
st = pd.read_excel('weekly_2021.xls')
st.iloc[:, 4:] = st.iloc[:, 4:].applymap(lambda x: x*1000 if x < 100 else x)
st['Week Ending Date'] = pd.to_datetime(st['Week Ending Date'], format='%m%Y')

# %%
gt = pd.read_excel('weekly1419.xls')
gt = gt.iloc[:, :17]
gt.iloc[:, 4:] = gt.iloc[:, 4:].applymap(lambda x: x*1000 if x < 100 else x)
gt['Week Ending Date'] = pd.to_datetime(gt['Week Ending Date'])

# %%
USA = st[st['Jurisdiction of Occurrence'].str.contains('United States')]
USA2 = gt[gt['Jurisdiction of Occurrence'].str.contains('United States')]

# %%
STATES = st.iloc[63:, :-2]
STATES2 = gt.iloc[63:, :]

# %%
USA2 = USA2.rename(columns = {'All  Cause': 'All Cause',
                     'Influenza and pneumonia (J10-J18)': 'Influenza and pneumonia (J09-J18)'})

STATES2 = STATES2.rename(columns = {'All  Cause': 'All Cause',
                     'Influenza and pneumonia (J10-J18)': 'Influenza and pneumonia (J09-J18)'})

# %%
USA

# %%
USA = USA[['Jurisdiction of Occurrence', 'MMWR Year', 'MMWR Week',
       'Week Ending Date', 'All Cause', 'Natural Cause',
       'Septicemia (A40-A41)', 'Malignant neoplasms (C00-C97)',
       'Diabetes mellitus (E10-E14)', 'Alzheimer disease (G30)',
       'Influenza and pneumonia (J09-J18)',
       'Chronic lower respiratory diseases (J40-J47)',
       'Other diseases of respiratory system (J00-J06,J30-J39,J67,J70-J98)',
       'Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)',
       'Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified (R00-R99)',
       'Diseases of heart (I00-I09,I11,I13,I20-I51)',
       'Cerebrovascular diseases (I60-I69)', 'COVID-19 (U071, Multiple Cause of Death)',
        'COVID-19 (U071, Underlying Cause of Death)']]

# %%
USA = pd.concat([USA2, USA])
STATES = pd.concat([STATES2, STATES])

# %%
STATES[STATES['MMWR Year'] > 2019].sample(20)

# %%
st.loc[:,'All Cause'] = st.loc[:,'All Cause'].apply(lambda x: x*1000 if x < 20 else x)
st.loc[:,'Natural Cause'] = st.loc[:,'Natural Cause'].apply(lambda x: x*1000 if x < 20 else x)
st.loc[:,'Malignant neoplasms (C00-C97)'] = st.loc[:,'Malignant neoplasms (C00-C97)'].apply(lambda x: x*1000 if x < 10 else x)
st.loc[:,'Diseases of heart (I00-I09,I11,I13,I20-I51)'] = st.loc[:,'Diseases of heart (I00-I09,I11,I13,I20-I51)'].apply(lambda x: x*1000 if x < 10 else x)
st.loc[:,'COVID-19 (U071, Multiple Cause of Death)'] = st.loc[:,'COVID-19 (U071, Multiple Cause of Death)'].apply(lambda x: x*1000 if x < 10 else x)
st.loc[:,'COVID-19 (U071, Underlying Cause of Death)'] = st.loc[:,'COVID-19 (U071, Underlying Cause of Death)'].apply(lambda x: x*1000 if x < 10 else x)

# %%
#STATES.iloc[:, 4:].applymap(lambda x: x*1000 if x < 10 else x)

# %%
#STATES = STATES.groupby(st['Week Ending Date'].dt.to_period('m')).sum().reset_index().drop(columns = ['MMWR Year','MMWR Week'])

# %%
dis = ['Natural Cause',
       'Septicemia (A40-A41)', 'Malignant neoplasms (C00-C97)',
       'Diabetes mellitus (E10-E14)', 'Alzheimer disease (G30)',
       'Influenza and pneumonia (J09-J18)',
       'Chronic lower respiratory diseases (J40-J47)',
       'Other diseases of respiratory system (J00-J06,J30-J39,J67,J70-J98)',
       'Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)',
       'Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified (R00-R99)',
       'Diseases of heart (I00-I09,I11,I13,I20-I51)',
       'Cerebrovascular diseases (I60-I69)']

# %%
GG = USA[['Natural Cause',
       'Septicemia (A40-A41)', 'Malignant neoplasms (C00-C97)',
       'Diabetes mellitus (E10-E14)', 'Alzheimer disease (G30)',
       'Influenza and pneumonia (J09-J18)',
       'Chronic lower respiratory diseases (J40-J47)',
       'Other diseases of respiratory system (J00-J06,J30-J39,J67,J70-J98)',
       'Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)',
       'Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified (R00-R99)',
       'Diseases of heart (I00-I09,I11,I13,I20-I51)',
       'Cerebrovascular diseases (I60-I69)']]

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# Maybe you needed to display plot in jupyter notebook
import plotly.offline as pyo
pyo.init_notebook_mode()

# Load exmples data
df = pd.read_csv('USA_diseases.csv')

# Base plot
fig = go.Figure(
    layout=go.Layout(
        updatemenus=[dict(type="buttons", direction="right", x=3.3, y=1.4), ],
        xaxis=dict(range=["2014-04-01", "2021-03-13"],
                   autorange=False, tickwidth=2,
                   title_text="Time"),
        yaxis=dict(range=[6, 15],
                   autorange=False,
                   title_text="Disease"),
        title="Diseases",
    ))

# Add traces
init = 1

fig.add_trace(
    go.Scatter(x=df['Week Ending Date'],
               y=np.log2(df['All Cause'])[:init],
               name="All",
               visible=True,
               line=dict(color="#33CFA5"),
                  mode = 'lines'))

fig.add_trace(
    go.Scatter(x=df['Week Ending Date'][:init],
               y=np.log2(df['Natural Cause'])[:init],
               name="Natural Cause",
               visible=True,
               line=dict(color="#bf00ff"),
              mode = 'lines'))


fig.add_trace(
    go.Scatter(x=df['Week Ending Date'][:init],
               y=np.log2(df['Septicemia'])[:init],
               name="Septicemia",
               visible=True,
               line=dict(color="#ff0000"),
              mode = 'lines'))

fig.add_trace(
    go.Scatter(x=df['Week Ending Date'],
               y=np.log2(df['Malignant neoplasms'])[:init],
               name="Malignant neoplasms",
               visible=True,
               line=dict(color='#f0f921'),
                  mode = 'lines')) 
fig.add_trace(
    go.Scatter(x=df['Week Ending Date'][:init],
               y=np.log2(df['Diabetes mellitus'])[:init],
               name="Diabetes mellitus",
               visible=True,
               line=dict(color='#fdca26'),
              mode = 'lines'))


fig.add_trace(
    go.Scatter(x=df['Week Ending Date'][:init],
               y=np.log2(df['Alzheimer'])[:init],
               name="Alzheimer",
               visible=True,
               line=dict(color='#ed7953'),
              mode = 'lines'))

fig.add_trace(
    go.Scatter(x=df['Week Ending Date'],
               y=np.log2(df['Influenza and pneumonia'])[:init],
               name="Influenza and pneumonia",
               visible=True,
               line=dict(color='#fb9f3a'),
                  mode = 'lines'))

fig.add_trace(
    go.Scatter(x=df['Week Ending Date'][:init],
               y=np.log2(df['Chronic lower respiratory'])[:init],
               name="Chronic lower respiratory",
               visible=True,
               line=dict(color='#d8576b'),
              mode = 'lines'))


fig.add_trace(
    go.Scatter(x=df['Week Ending Date'][:init],
               y=np.log2(df['Other diseases of respiratory system'])[:init],
               name="Other diseases of respiratory system",
               visible=True,
               line=dict(color='#bd3786'),
              mode = 'lines'))

fig.add_trace(
    go.Scatter(x=df['Week Ending Date'],
               y=np.log2(df['Nephritis, nephrotic syndrome and nephrosis'])[:init],
               name="Nephritis, nephrotic syndrome and nephrosis",
               visible=True,
               line=dict(color='#9c179e'),
                  mode = 'lines'))

fig.add_trace(
    go.Scatter(x=df['Week Ending Date'][:init],
               y=np.log2(df['Symptoms, signs and abnormal clinical and laboratory findings'])[:init],
               name="Abnormal",
               visible=True,
               line=dict(color='#0d0887'),
              mode = 'lines'))


fig.add_trace(
    go.Scatter(x=df['Week Ending Date'][:init],
               y=np.log2(df['Diseases of heart'])[:init],
               name="Diseases of heart",
               visible=True,
               line=dict(color='#46039f'),
              mode = 'lines'))

fig.add_trace(
    go.Scatter(x=df['Week Ending Date'][:init],
               y=np.log2(df['Cerebrovascular diseases'])[:init],
               name="Cerebrovascular diseases",
               visible=True,
               line=dict(color='#7201a8'),
              mode = 'lines'))
# Animation
fig.update(frames=[
    go.Frame(
        data=[
            go.Scatter(x=df['Week Ending Date'][:k], y=np.log2(df['All Cause'])[:k]),
            go.Scatter(x=df['Week Ending Date'][:k], y=np.log2(df['Natural Cause'])[:k]),
            go.Scatter(x=df['Week Ending Date'][:k], y=np.log2(df['Septicemia'])[:k]),
            go.Scatter(x=df['Week Ending Date'][:k], y=np.log2(df['Malignant neoplasms'])[:k]),
            go.Scatter(x=df['Week Ending Date'][:k], y=np.log2(df['Diabetes mellitus'])[:k]),
            go.Scatter(x=df['Week Ending Date'][:k], y=np.log2(df['Alzheimer'])[:k]),
            go.Scatter(x=df['Week Ending Date'][:k], y=np.log2(df['Influenza and pneumonia'])[:k]),
            go.Scatter(x=df['Week Ending Date'][:k], y=np.log2(df['Chronic lower respiratory'])[:k]),
            go.Scatter(x=df['Week Ending Date'][:k], y=np.log2(df['Other diseases of respiratory system'])[:k]),
            go.Scatter(x=df['Week Ending Date'][:k], y=np.log2(df['Nephritis, nephrotic syndrome and nephrosis'])[:k]),
            go.Scatter(x=df['Week Ending Date'][:k], y=np.log2(df['Symptoms, signs and abnormal clinical and laboratory findings'])[:k]),
            go.Scatter(x=df['Week Ending Date'][:k], y=np.log2(df['Diseases of heart'])[:k]),
            go.Scatter(x=df['Week Ending Date'][:k], y=np.log2(df['Cerebrovascular diseases'])[:k])
        ])
    for k in range(init, len(df)+1)])


# Extra Formatting
fig.update_xaxes(ticks="outside", tickwidth=2, tickcolor='white', ticklen=10)
fig.update_yaxes(ticks="outside", tickwidth=2, tickcolor='white', ticklen=1)
fig.update_layout(yaxis_tickformat='-')
fig.update_layout(legend=dict(x=0, y=1.1), legend_orientation="h")

# Buttons
fig.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                dict(label="Play",
                        method="animate",
                    args=[None, {"frame": {"duration": 1}}]),

                 dict(label="Diabetes",
                    method="update",
                    args=[{"visible": [False, True, False, False, False, False, False, False, False,False, False, False, False, False]},
                          {"showlegend": True}]),
                
                dict(label="Influenza & pnemonia",
                    method="update",
                    args=[{"visible": [True, False, False, False, False, False, False, False, False,False, False, False, False, False]},
                          {"showlegend": True}]),
                
                dict(label="Abnormal",
                    method="update",
                    args=[{"visible": [False, False, True, False, False, False, False, False, False,False, False, False, False, False]},
                          {"showlegend": True}]),
                
                    dict(label="Malignant neoplasms",
                    method="update",
                    args=[{"visible": [False, False, False,False,True,False, False, False, False, False,False, False, False, False]},
                          {"showlegend": True}]),
                
                    dict(label="Alzheimer disease",
                    method="update",
                    args=[{"visible": [False, False, False,False,False,True,False, False, False,False,False, False,False,False]},
                          {"showlegend": True}]),
                
                    dict(label="Chronic lower respiratory diseases",
                    method="update",
                    args=[{"visible": [False, False, False,False,False,False,True, False, False,False,False, False,False,False]},
                          {"showlegend": True}]),
                
                    dict(label="Other diseases of respiratory system",
                    method="update",
                    args=[{"visible": [False, False, False,False,False,False,False,True, False, False, False,False,False,False]},
                          {"showlegend": True}]),
                
                    dict(label="Nephritis, nephrotic syndrome and nephrosis",
                    method="update",
                    args=[{"visible": [False, False, False,False,False,False,False,False,True, False, False,False,False,False]},
                          {"showlegend": True}]),
                
                    dict(label="Diseases of heart",
                    method="update",
                    args=[{"visible": [False, False, False,False,False,False,False,False,False,True,False, False, False,False]},
                          {"showlegend": True}]),
                
                    dict(label="Cerebrovascular diseases",
                    method="update",
                    args=[{"visible": [False, False, False,False,False,False,False,False,False,False,True,False, False, False]},
                          {"showlegend": True}]),
                
                    dict(label="Symptoms, signs and abnormal clinical and laboratory findings",
                    method="update",
                    args=[{"visible": [False, False, False,False,False,False,False,False,False,False,False,True,False, False]},
                          {"showlegend": True}]),
                
                dict(label="Septicemia",
                    method="update",
                    args=[{"visible": [False, False, False,False,False,False,False,False,False,False,False,False,True,False]},
                          {"showlegend": True}]),
                dict(label="All",
                    method="update",
                    args=[{"visible": [True, True, True, True,True, True, True, True,True, True, True, True,True, True]},
                          {"showlegend": True}])
                ]))])



fig.show()

# %%
df1

# %%
import plotly.graph_objects as go
import numpy as np

title = 'Main Source for News'
labels = ['Television', 'Newspaper', 'Internet', 'Radio']
colors = ['rgb(67,67,67)', 'rgb(115,115,115)', 'rgb(49,130,189)', 'rgb(189,189,189)']

mode_size = [8, 8, 12, 8]
line_size = [2, 2, 4, 2]

x_data = np.vstack((np.arange(2001, 2014),)*4)

y_data = np.array([
    [74, 82, 80, 74, 73, 72, 74, 70, 70, 66, 66, 69],
    [45, 42, 50, 46, 36, 36, 34, 35, 32, 31, 31, 28],
    [13, 14, 20, 24, 20, 24, 24, 40, 35, 41, 43, 50],
    [18, 21, 18, 21, 16, 14, 13, 18, 17, 16, 19, 23],
])

fig = go.Figure()

for i in range(0, 4):
    fig.add_trace(go.Scatter(x=x_data[i], y=y_data[i], mode='lines',
        name=labels[i],
        line=dict(color=colors[i], width=line_size[i]),
        connectgaps=True,
    ))

    # endpoints
    fig.add_trace(go.Scatter(
        x=[x_data[i][0], x_data[i][-1]],
        y=[y_data[i][0], y_data[i][-1]],
        mode='markers',
        marker=dict(color=colors[i], size=mode_size[i])
    ))

fig.update_layout(
    xaxis=dict(
        showline=True,
        showgrid=False,
        showticklabels=True,
        linecolor='rgb(204, 204, 204)',
        linewidth=2,
        ticks='outside',
        tickfont=dict(
            family='Arial',
            size=12,
            color='rgb(82, 82, 82)',
        ),
    ),
    yaxis=dict(
        showgrid=False,
        zeroline=False,
        showline=False,
        showticklabels=False,
    ),
    autosize=False,
    margin=dict(
        autoexpand=False,
        l=100,
        r=20,
        t=110,
    ),
    showlegend=False,
    plot_bgcolor='white'
)

annotations = []

# Adding labels
for y_trace, label, color in zip(y_data, labels, colors):
    # labeling the left_side of the plot
    annotations.append(dict(xref='paper', x=0.05, y=y_trace[0],
                                  xanchor='right', yanchor='middle',
                                  text=label + ' {}%'.format(y_trace[0]),
                                  font=dict(family='Arial',
                                            size=16),
                                  showarrow=False))
    # labeling the right_side of the plot
    annotations.append(dict(xref='paper', x=0.95, y=y_trace[11],
                                  xanchor='left', yanchor='middle',
                                  text='{}%'.format(y_trace[11]),
                                  font=dict(family='Arial',
                                            size=16),
                                  showarrow=False))
# Title
annotations.append(dict(xref='paper', yref='paper', x=0.0, y=1.05,
                              xanchor='left', yanchor='bottom',
                              text='Main Source for News',
                              font=dict(family='Arial',
                                        size=30,
                                        color='rgb(37,37,37)'),
                              showarrow=False))
# Source
annotations.append(dict(xref='paper', yref='paper', x=0.5, y=-0.1,
                              xanchor='center', yanchor='top',
                              text='Source: PewResearch Center & ' +
                                   'Storytelling with data',
                              font=dict(family='Arial',
                                        size=12,
                                        color='rgb(150,150,150)'),
                              showarrow=False))

fig.update_layout(annotations=annotations)

fig.show()

# %%
gg = pd.read_csv('USA_DISEASES.csv').drop(columns = ['Unnamed: 0','MMWR Week','MMWR Year','Jurisdiction of Occurrence'])

gg['Week Ending Date'] = pd.to_datetime(gg['Week Ending Date'])
gg = gg.set_index('Week Ending Date')
    
df1 = gg.groupby(pd.Grouper(freq="Y")).mean().reset_index()
